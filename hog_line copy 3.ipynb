# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "image/01.jpg"

img = cv2.imread(path)
img = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,27,4)
plt.imshow(img,cmap = "gray")
plt.show()

# %%
#https://www.geeksforgeeks.org/line-detection-python-opencv-houghline-method/
import cv2
import numpy as np
import matplotlib.pyplot as plt
path = "image/01.jpg"
image = cv2.imread(path)
img = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21) #lọc nhiễu ảnh
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)	#chuyển sang ảnh xám
img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,27,4) 
#to detect coutour of image using gaussian filter. Adjust 2 last params to match your image

# Apply HoughLinesP method to
# to directly obtain line end points
lines = cv2.HoughLinesP(
			img, # Input edge image
			1, # Distance resolution in pixels
			np.pi/180, # Angle resolution in radians
			threshold=100, # Min number of votes for valid line
			minLineLength=100, # Min allowed length of line
			maxLineGap=2 # Max allowed gap between line for joining them
			)
rows = img.shape[0]
# Apply HoughCircles method to
# to directly obtain line end points
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 1, rows / 8,
							param1=200, param2=30,
							minRadius=1, maxRadius=1000)

center_shape=[] #mảng lưu tâm tất cả shape 
#CIRCLE
if circles is not None:
	circles = np.uint16(np.around(circles))
	for i in circles[0, :]:
		center = (i[0], i[1])
		# circle center
		cv2.circle(image, center, 5, (0, 100, 100), 3)
		# circle outline
		radius = i[2]
		#print(radius)
		cv2.circle(image, center, radius, (255, 0, 255), 3)
		print("The Circle Dectected: Center = (%2.2f, %2.2f), Radius = %2.2f"%(i[0], i[1], i[2]))
		center_shape.append([center])
else:
	print("Do not dectect the Circle")
	center_shape.append([None])

#RECTANGLE
if lines is not None:
	d=[] # chưa độ dài các cạnh được dectect
	for i, points  in enumerate(lines):
		x1,y1,x2,y2=points[0]
		d.append([i,np.sqrt(pow((x2-x1),2)+pow((y2-y1),2))])
	d = np.array(d)
	d_=np.flip(np.argsort(d[:,1],kind='mergesort')) #sort từ lớn đến bé

	lines_list =[] #mảng lưu tọa độ đoạn thẳng
	cent_list = [] #mảng lưu trung điểm đoạn thẳng
	for stt, i in enumerate(d_): #Lọc 2 cạnh đối nhau của hình vuông
		x1,y1,x2,y2=lines[i][0] #lấy tọa độ cạnh
		#tìm trung điểm cạnh
		x_av = int(np.floor(abs(abs(x1+x2))/2))
		y_av = int(np.floor(abs(abs(y1+y2))/2))
		if stt == 0: #lưu cạnh độ dài lớn nhất 
			d_1_x = x_av
			d_1_y = y_av
			cv2.line(image,(x1,y1),(x2,y2),(0,255,0),3)
			cv2.drawMarker(image, (x_av, y_av),(0,0,255), markerType=cv2.MARKER_STAR, markerSize=40, thickness=1, line_type=cv2.LINE_AA)
			# Maintain a simples lookup list for points
			lines_list.append([(x1,y1),(x2,y2)])
			cent_list.append([d_1_x,d_1_y])
		d_break = np.sqrt(pow((d_1_x-x_av),2)+pow((d_1_y-y_av),2))
		
		if d_break > 250 and d_break < 350:	#tìm cạnh đối
			cv2.line(image,(x1,y1),(x2,y2),(255,255,0),3)
			cv2.drawMarker(image, (x_av, y_av),(0,0,255), markerType=cv2.MARKER_STAR, markerSize=40, thickness=1, line_type=cv2.LINE_AA)
			# Maintain a simples lookup list for points
			lines_list.append([(x1,y1),(x2,y2)])
			cent_list.append([x_av,y_av])
			break
	#print(len(lines_list),d)
	x_cen = int(np.floor(abs(abs(cent_list[0][0]+cent_list[1][0]))/2))
	y_cen = int(np.floor(abs(abs(cent_list[0][1]+cent_list[1][1]))/2))
	cv2.drawMarker(image, (x_cen, y_cen),(255,0,255), markerType=cv2.MARKER_STAR, markerSize=40, thickness=1, line_type=cv2.LINE_AA)
	print("The rectangle dectected: Center = (%2.2f, %2.2f), Side length= %2.2f"%(x_cen, y_cen, d_break))
	center_shape.append([x_cen,y_cen])
else:
	print("Do not dectect the Rectangle")
	center_shape.append([None])
plt.imshow(image)
plt.show()
# Out:
# The Circle Dectected: Center = (880.00, 322.00), Radius = 332.00
# The Circle Dectected: Center = (336.00, 238.00), Radius = 229.00
# The Circle Dectected: Center = (326.00, 440.00), Radius = 241.00
# The Circle Dectected: Center = (788.00, 322.00), Radius = 233.00
# The Circle Dectected: Center = (432.00, 356.00), Radius = 253.00
# The Circle Dectected: Center = (232.00, 234.00), Radius = 225.00
# The Circle Dectected: Center = (880.00, 416.00), Radius = 239.00
# The Circle Dectected: Center = (606.00, 524.00), Radius = 240.00
# The Circle Dectected: Center = (992.00, 334.00), Radius = 229.00
# The Circle Dectected: Center = (612.00, 324.00), Radius = 239.00
# The Circle Dectected: Center = (414.00, 694.00), Radius = 237.00
# The Circle Dectected: Center = (252.00, 324.00), Radius = 223.00
# The Circle Dectected: Center = (974.00, 146.00), Radius = 132.00
# The Circle Dectected: Center = (528.00, 718.00), Radius = 342.00
# The Circle Dectected: Center = (488.00, 250.00), Radius = 215.00
# The Circle Dectected: Center = (494.00, 424.00), Radius = 221.00
# The Circle Dectected: Center = (316.00, 150.00), Radius = 148.00
# The Circle Dectected: Center = (778.00, 426.00), Radius = 138.00
# The Circle Dectected: Center = (234.00, 416.00), Radius = 150.00
# The Circle Dectected: Center = (1258.00, 402.00), Radius = 245.00
# The Circle Dectected: Center = (500.00, 526.00), Radius = 151.00
# The Circle Dectected: Center = (996.00, 692.00), Radius = 228.00
# The Circle Dectected: Center = (518.00, 142.00), Radius = 154.00
# The Circle Dectected: Center = (596.00, 424.00), Radius = 139.00
# The Circle Dectected: Center = (1068.00, 246.00), Radius = 133.00
# The Circle Dectected: Center = (1062.00, 442.00), Radius = 149.00
# The Circle Dectected: Center = (158.00, 154.00), Radius = 144.00
# The Circle Dectected: Center = (48.00, 142.00), Radius = 139.00
# The Circle Dectected: Center = (972.00, 522.00), Radius = 138.00
# The Circle Dectected: Center = (882.00, 22.00), Radius = 234.00
# The Circle Dectected: Center = (706.00, 372.00), Radius = 175.00
# The Circle Dectected: Center = (882.00, 574.00), Radius = 142.00
# The Circle Dectected: Center = (1072.00, 140.00), Radius = 146.00
# The Circle Dectected: Center = (234.00, 616.00), Radius = 149.00
# The Circle Dectected: Center = (684.00, 714.00), Radius = 249.00
# The Circle Dectected: Center = (788.00, 712.00), Radius = 248.00
# The Circle Dectected: Center = (598.00, 232.00), Radius = 144.00
# The Circle Dectected: Center = (62.00, 334.00), Radius = 127.00
# The Circle Dectected: Center = (1148.00, 412.00), Radius = 136.00
# The Circle Dectected: Center = (132.00, 498.00), Radius = 150.00
# The Circle Dectected: Center = (704.00, 584.00), Radius = 147.00
# The Circle Dectected: Center = (690.00, 136.00), Radius = 144.00
# The Circle Dectected: Center = (412.00, 136.00), Radius = 144.00
# The Circle Dectected: Center = (342.00, 342.00), Radius = 134.00
# The Circle Dectected: Center = (784.00, 82.00), Radius = 144.00
# The Circle Dectected: Center = (420.00, 588.00), Radius = 139.00
# The Circle Dectected: Center = (1254.00, 234.00), Radius = 132.00
# The Circle Dectected: Center = (1250.00, 46.00), Radius = 239.00
# The Circle Dectected: Center = (324.00, 610.00), Radius = 136.00
# The Circle Dectected: Center = (1264.00, 528.00), Radius = 155.00
# The Circle Dectected: Center = (36.00, 496.00), Radius = 144.00
# The Circle Dectected: Center = (420.00, 480.00), Radius = 138.00
# The Circle Dectected: Center = (126.00, 704.00), Radius = 156.00
# The Circle Dectected: Center = (1150.00, 518.00), Radius = 120.00
# The Circle Dectected: Center = (104.00, 66.00), Radius = 92.00
# The Circle Dectected: Center = (158.00, 334.00), Radius = 136.00
# The Circle Dectected: Center = (674.00, 38.00), Radius = 160.00
# The Circle Dectected: Center = (250.00, 512.00), Radius = 127.00
# The Circle Dectected: Center = (314.00, 700.00), Radius = 153.00
# The Circle Dectected: Center = (790.00, 542.00), Radius = 94.00
# The Circle Dectected: Center = (1252.00, 696.00), Radius = 142.00
# The Circle Dectected: Center = (878.00, 712.00), Radius = 158.00
# The Circle Dectected: Center = (1084.00, 46.00), Radius = 150.00
# The Circle Dectected: Center = (830.00, 174.00), Radius = 89.00
# The Circle Dectected: Center = (1164.00, 240.00), Radius = 45.00
# The Circle Dectected: Center = (514.00, 48.00), Radius = 134.00
# The Circle Dectected: Center = (1076.00, 600.00), Radius = 54.00
# The Circle Dectected: Center = (326.00, 56.00), Radius = 55.00
# The Circle Dectected: Center = (1084.00, 716.00), Radius = 161.00
# The Circle Dectected: Center = (1178.00, 130.00), Radius = 73.00
# The Circle Dectected: Center = (694.00, 232.00), Radius = 55.00
# The Circle Dectected: Center = (46.00, 604.00), Radius = 47.00
# The Circle Dectected: Center = (974.00, 240.00), Radius = 47.00
# The Circle Dectected: Center = (216.00, 56.00), Radius = 55.00
# The Circle Dectected: Center = (136.00, 606.00), Radius = 52.00
# The Circle Dectected: Center = (714.00, 490.00), Radius = 57.00
# The Circle Dectected: Center = (26.00, 718.00), Radius = 160.00
# The Circle Dectected: Center = (970.00, 430.00), Radius = 54.00
# The Circle Dectected: Center = (142.00, 242.00), Radius = 55.00
# The Circle Dectected: Center = (972.00, 52.00), Radius = 48.00
# The Circle Dectected: Center = (46.00, 246.00), Radius = 47.00
# The Circle Dectected: Center = (220.00, 720.00), Radius = 155.00
# The Circle Dectected: Center = (1182.00, 610.00), Radius = 56.00
# The Circle Dectected: Center = (516.00, 616.00), Radius = 50.00
# The Circle Dectected: Center = (618.00, 614.00), Radius = 52.00
# The Circle Dectected: Center = (418.00, 46.00), Radius = 47.00
# The Circle Dectected: Center = (1082.00, 346.00), Radius = 62.00
# The Circle Dectected: Center = (1188.00, 330.00), Radius = 54.00
# The Circle Dectected: Center = (1268.00, 142.00), Radius = 51.00
# The rectangle dectected: Center = (347.00, 59.00), Side length= 255.79

# %%
center_shape #Tâm đường tròn, tâm hình vuông
# Out:
# [[(880, 322)],
#  [(336, 238)],
#  [(326, 440)],
#  [(788, 322)],
#  [(432, 356)],
#  [(232, 234)],
#  [(880, 416)],
#  [(606, 524)],
#  [(992, 334)],
#  [(612, 324)],
#  [(414, 694)],
#  [(252, 324)],
#  [(974, 146)],
#  [(528, 718)],
#  [(488, 250)],
#  [(494, 424)],
#  [(316, 150)],
#  [(778, 426)],
#  [(234, 416)],
#  [(1258, 402)],
#  [(500, 526)],
#  [(996, 692)],
#  [(518, 142)],
#  [(596, 424)],
#  [(1068, 246)],
#  [(1062, 442)],
#  [(158, 154)],
#  [(48, 142)],
#  [(972, 522)],
#  [(882, 22)],
#  [(706, 372)],
#  [(882, 574)],
#  [(1072, 140)],
#  [(234, 616)],
#  [(684, 714)],
#  [(788, 712)],
#  [(598, 232)],
#  [(62, 334)],
#  [(1148, 412)],
#  [(132, 498)],
#  [(704, 584)],
#  [(690, 136)],
#  [(412, 136)],
#  [(342, 342)],
#  [(784, 82)],
#  [(420, 588)],
#  [(1254, 234)],
#  [(1250, 46)],
#  [(324, 610)],
#  [(1264, 528)],
#  [(36, 496)],
#  [(420, 480)],
#  [(126, 704)],
#  [(1150, 518)],
#  [(104, 66)],
#  [(158, 334)],
#  [(674, 38)],
#  [(250, 512)],
#  [(314, 700)],
#  [(790, 542)],
#  [(1252, 696)],
#  [(878, 712)],
#  [(1084, 46)],
#  [(830, 174)],
#  [(1164, 240)],
#  [(514, 48)],
#  [(1076, 600)],
#  [(326, 56)],
#  [(1084, 716)],
#  [(1178, 130)],
#  [(694, 232)],
#  [(46, 604)],
#  [(974, 240)],
#  [(216, 56)],
#  [(136, 606)],
#  [(714, 490)],
#  [(26, 718)],
#  [(970, 430)],
#  [(142, 242)],
#  [(972, 52)],
#  [(46, 246)],
#  [(220, 720)],
#  [(1182, 610)],
#  [(516, 616)],
#  [(618, 614)],
#  [(418, 46)],
#  [(1082, 346)],
#  [(1188, 330)],
#  [(1268, 142)],
#  [347, 59]]
